# %%
from bs4 import BeautifulSoup
import requests

# %%
url ='https://www.datacamp.com/courses/merging-dataframes-with-pandas'

# %%
r = requests.get(url)
text = r.text

# %%
soup = BeautifulSoup(text, 'lxml')

# %%
tag = soup.findAll('h5')

# %% [markdown]
# ## Sub List

# %%
sub_list =[i.text for i in tag]
sub_list
# Out:
# ['Learn',
#  'Pricing',
#  'Plans',
#  'Courses',
#  'Tracks',
#  'Instructors',
#  'Reading multiple data files',
#  'Reading DataFrames from multiple files',
#  'Reading DataFrames from multiple files in a loop',
#  'Combining DataFrames from multiple data files',
#  'Reindexing DataFrames',
#  'Sorting DataFrame with the Index & columns',
#  'Reindexing DataFrame from a list',
#  'Reindexing using another DataFrame Index',
#  'Arithmetic with Series & DataFrames',
#  'Adding unaligned DataFrames',
#  'Broadcasting in arithmetic formulas',
#  'Computing percentage growth of GDP',
#  'Converting currency of stocks',
#  'Merging DataFrames',
#  'Merging company DataFrames',
#  'Merging on a specific column',
#  'Merging on columns with non-matching labels',
#  'Merging on multiple columns',
#  'Joining DataFrames',
#  'Joining by Index',
#  'Choosing a joining strategy',
#  'Left & right merging on multiple columns',
#  'Merging DataFrames with outer join',
#  'Ordered merges',
#  'Using merge_ordered()',
#  'Using merge_asof()',
#  'Appending & concatenating Series',
#  'Appending Series with nonunique Indices',
#  'Appending pandas Series',
#  'Concatenating pandas Series along row axis',
#  'Appending & concatenating DataFrames',
#  'Appending DataFrames with ignore_index',
#  'Concatenating pandas DataFrames along column axis',
#  'Reading multiple files to build a DataFrame',
#  'Concatenation, keys, & MultiIndexes',
#  'Concatenating vertically to get MultiIndexed rows',
#  'Slicing MultiIndexed DataFrames',
#  'Concatenating horizontally to get MultiIndexed columns',
#  'Concatenating DataFrames from a dict',
#  'Outer & inner joins',
#  'Concatenating DataFrames with inner join',
#  'Resampling & concatenating DataFrames with inner join',
#  'Medals in the Summer Olympics',
#  'Loading Olympic edition DataFrame',
#  'Loading IOC codes DataFrame',
#  'Building medals DataFrame',
#  'Quantifying Performance',
#  'Counting medals by country/edition in a pivot table',
#  'Computing fraction of medals per Olympic edition',
#  'Computing percentage change in fraction of medals won',
#  'Reshaping and plotting',
#  'Building hosts DataFrame',
#  'Reshaping for analysis',
#  'Merging to compute influence',
#  'Plotting influence of host country',
#  'Final thoughts',
#  'Reading multiple data files',
#  'Reading DataFrames from multiple files',
#  'Reading DataFrames from multiple files in a loop',
#  'Combining DataFrames from multiple data files',
#  'Reindexing DataFrames',
#  'Sorting DataFrame with the Index & columns',
#  'Reindexing DataFrame from a list',
#  'Reindexing using another DataFrame Index',
#  'Arithmetic with Series & DataFrames',
#  'Adding unaligned DataFrames',
#  'Broadcasting in arithmetic formulas',
#  'Computing percentage growth of GDP',
#  'Converting currency of stocks',
#  'Appending & concatenating Series',
#  'Appending Series with nonunique Indices',
#  'Appending pandas Series',
#  'Concatenating pandas Series along row axis',
#  'Appending & concatenating DataFrames',
#  'Appending DataFrames with ignore_index',
#  'Concatenating pandas DataFrames along column axis',
#  'Reading multiple files to build a DataFrame',
#  'Concatenation, keys, & MultiIndexes',
#  'Concatenating vertically to get MultiIndexed rows',
#  'Slicing MultiIndexed DataFrames',
#  'Concatenating horizontally to get MultiIndexed columns',
#  'Concatenating DataFrames from a dict',
#  'Outer & inner joins',
#  'Concatenating DataFrames with inner join',
#  'Resampling & concatenating DataFrames with inner join',
#  'Merging DataFrames',
#  'Merging company DataFrames',
#  'Merging on a specific column',
#  'Merging on columns with non-matching labels',
#  'Merging on multiple columns',
#  'Joining DataFrames',
#  'Joining by Index',
#  'Choosing a joining strategy',
#  'Left & right merging on multiple columns',
#  'Merging DataFrames with outer join',
#  'Ordered merges',
#  'Using merge_ordered()',
#  'Using merge_asof()',
#  'Medals in the Summer Olympics',
#  'Loading Olympic edition DataFrame',
#  'Loading IOC codes DataFrame',
#  'Building medals DataFrame',
#  'Quantifying Performance',
#  'Counting medals by country/edition in a pivot table',
#  'Computing fraction of medals per Olympic edition',
#  'Computing percentage change in fraction of medals won',
#  'Reshaping and plotting',
#  'Building hosts DataFrame',
#  'Reshaping for analysis',
#  'Merging to compute influence',
#  'Plotting influence of host country',
#  'Final thoughts',
#  'Team Anaconda',
#  'Tracks',
#  'Collaborators',
#  'Prerequisites',
#  'Datasets']

# %%
sub_list= [
 'Introduction to Databases',
 'Relational Model',
 'Connecting to your Database',
 'Engines and Connection Strings',
 'Autoloading Tables from a Database',
 'Viewing Table Details',
 'Introduction to SQL',
 'Selecting data from a Table: raw SQL',
 'Selecting data from a Table with SQLAlchemy',
 'Handling a ResultSet',
 'Congratulations!',
 'Filtering and Targeting Data',
 'Connecting to a PostgreSQL Database',
 'Filter data selected from a Table - Simple',
 'Filter data selected from a Table - Expressions',
 'Filter data selected from a Table - Advanced',
 'Overview of Ordering',
 'Ordering by a Single Column',
 'Ordering in Descending Order by a Single Column',
 'Ordering by Multiple Columns',
 'Counting, Summing and Grouping Data',
 'Counting Distinct Data',
 'Count of Records by State',
 'Determining the Population Sum by State',
 "Let's use Pandas and Matplotlib to visualize our Data",
 'SQLAlchemy ResultsProxy and Pandas Dataframes',
 'From SQLAlchemy results to a Graph',
 'Calculating Values in a Query',
 'Connecting to a MySQL Database',
 'Calculating a Difference between Two Columns',
 'Determining the Overall Percentage of Females',
 'SQL Relationships',
 'Automatic Joins with an Established Relationship',
 'Joins',
 'More Practice with Joins',
 'Working with Hierarchical Tables',
 'Using alias to handle same table joined queries',
 'Leveraging Functions and Group_bys with Hierarchical Data',
 'Dealing with Large ResultSets',
 'Working on Blocks of Records',
 'Creating Databases and Tables',
 'Creating Tables with SQLAlchemy',
 'Constraints and Data Defaults',
 'Inserting Data into a Table',
 'Inserting a single row with an insert() statement',
 'Inserting Multiple Records at Once',
 'Loading a CSV into a Table',
 'Updating Data in a Database',
 'Updating individual records',
 'Updating Multiple Records',
 'Correlated Updates',
 'Removing Data From a Database',
 'Deleting all the records from a table',
 'Deleting specific records',
 'Deleting a Table Completely',
 'Census Case Study',
 'Setup the Engine and MetaData',
 'Create the Table to the Database',
 'Populating the Database',
 'Reading the Data from the CSV',
 'Load Data from a list into the Table',
 'Example Queries',
 'Build a Query to Determine the Average Age by Population',
 'Build a Query to Determine the Percentage of Population by Gender and State',
 'Build a Query to Determine the Difference by State from the 2000 and 2008 Censuses',
 'Congratulations']

# %%
len(sublist2)
# Out:
# 27

# %% [markdown]
# ## List of Dictionary for markdown

# %%
l1 = []
s2 = "### "
for i in sub_list:
    l1.append(s2+i)

# %%
l2 = []
s1 = "<p id ='"
s2 = "'><p>\n"
for i in sub_list:
    l2.append(s1+''.join([k[0] for k in i.split(' ')])+s2)

# %%
list_of_tuples=list(zip(l2, l1))

# %%
list_of_lists = [list(elem) for elem in list_of_tuples]

# %%
list_dict = []
for i in list_of_lists:
    list_dict.append({
   "cell_type": "markdown",
   "metadata": {},
   "source": i
  })

# %% [markdown]
# # Function to make Upper Links

# %%
def prettify(a):
    s = ''
    for i in a:
    
        s = s+'* ['+i+'](#'+ ''.join([k[0] for k in i.split(' ')])+')'+'\n'
    print(s)

# %% [markdown]
# ## Super List

# %%
sup_list =[i.text for i in headtag]
sup_list
# Out:
# ['Create Your Free Account',
#  '\n          Preparing data\n        ',
#  '\n          Merging data\n        ',
#  '\n          Concatenating data\n        ',
#  '\n          Case Study - Summer Olympics\n        ',
#  '\n          Preparing data\n        ',
#  '\n          Concatenating data\n        ',
#  '\n          Merging data\n        ',
#  '\n          Case Study - Summer Olympics\n        ',
#  'Get notified']

# %% [markdown]
# ## Pretify header for markdown

# %%
prettify(sub_list)
# Out:
# * [Learn](#L)
# * [Pricing](#P)
# * [Plans](#P)
# * [Courses](#C)
# * [Tracks](#T)
# * [Instructors](#I)
# * [Reading multiple data files](#Rmdf)
# * [Reading DataFrames from multiple files](#RDfmf)
# * [Reading DataFrames from multiple files in a loop](#RDfmfial)
# * [Combining DataFrames from multiple data files](#CDfmdf)
# * [Reindexing DataFrames](#RD)
# * [Sorting DataFrame with the Index & columns](#SDwtI&c)
# * [Reindexing DataFrame from a list](#RDfal)
# * [Reindexing using another DataFrame Index](#RuaDI)
# * [Arithmetic with Series & DataFrames](#AwS&D)
# * [Adding unaligned DataFrames](#AuD)
# * [Broadcasting in arithmetic formulas](#Biaf)
# * [Computing percentage growth of GDP](#CpgoG)
# * [Converting currency of stocks](#Ccos)
# * [Merging DataFrames](#MD)
# * [Merging company DataFrames](#McD)
# * [Merging on a specific column](#Moasc)
# * [Merging on columns with non-matching labels](#Mocwnl)
# * [Merging on multiple columns](#Momc)
# * [Joining DataFrames](#JD)
# * [Joining by Index](#JbI)
# * [Choosing a joining strategy](#Cajs)
# * [Left & right merging on multiple columns](#L&rmomc)
# * [Merging DataFrames with outer join](#MDwoj)
# * [Ordered merges](#Om)
# * [Using merge_ordered()](#Um)
# * [Using merge_asof()](#Um)
# * [Appending & concatenating Series](#A&cS)
# * [Appending Series with nonunique Indices](#ASwnI)
# * [Appending pandas Series](#ApS)
# * [Concatenating pandas Series along row axis](#CpSara)
# * [Appending & concatenating DataFrames](#A&cD)
# * [Appending DataFrames with ignore_index](#ADwi)
# * [Concatenating pandas DataFrames along column axis](#CpDaca)
# * [Reading multiple files to build a DataFrame](#RmftbaD)
# * [Concatenation, keys, & MultiIndexes](#Ck&M)
# * [Concatenating vertically to get MultiIndexed rows](#CvtgMr)
# * [Slicing MultiIndexed DataFrames](#SMD)
# * [Concatenating horizontally to get MultiIndexed columns](#ChtgMc)
# * [Concatenating DataFrames from a dict](#CDfad)
# * [Outer & inner joins](#O&ij)
# * [Concatenating DataFrames with inner join](#CDwij)
# * [Resampling & concatenating DataFrames with inner join](#R&cDwij)
# * [Medals in the Summer Olympics](#MitSO)
# * [Loading Olympic edition DataFrame](#LOeD)
# * [Loading IOC codes DataFrame](#LIcD)
# * [Building medals DataFrame](#BmD)
# * [Quantifying Performance](#QP)
# * [Counting medals by country/edition in a pivot table](#Cmbciapt)
# * [Computing fraction of medals per Olympic edition](#CfompOe)
# * [Computing percentage change in fraction of medals won](#Cpcifomw)
# * [Reshaping and plotting](#Rap)
# * [Building hosts DataFrame](#BhD)
# * [Reshaping for analysis](#Rfa)
# * [Merging to compute influence](#Mtci)
# * [Plotting influence of host country](#Piohc)
# * [Final thoughts](#Ft)
# * [Reading multiple data files](#Rmdf)
# * [Reading DataFrames from multiple files](#RDfmf)
# * [Reading DataFrames from multiple files in a loop](#RDfmfial)
# * [Combining DataFrames from multiple data files](#CDfmdf)
# * [Reindexing DataFrames](#RD)
# * [Sorting DataFrame with the Index & columns](#SDwtI&c)
# * [Reindexing DataFrame from a list](#RDfal)
# * [Reindexing using another DataFrame Index](#RuaDI)
# * [Arithmetic with Series & DataFrames](#AwS&D)
# * [Adding unaligned DataFrames](#AuD)
# * [Broadcasting in arithmetic formulas](#Biaf)
# * [Computing percentage growth of GDP](#CpgoG)
# * [Converting currency of stocks](#Ccos)
# * [Appending & concatenating Series](#A&cS)
# * [Appending Series with nonunique Indices](#ASwnI)
# * [Appending pandas Series](#ApS)
# * [Concatenating pandas Series along row axis](#CpSara)
# * [Appending & concatenating DataFrames](#A&cD)
# * [Appending DataFrames with ignore_index](#ADwi)
# * [Concatenating pandas DataFrames along column axis](#CpDaca)
# * [Reading multiple files to build a DataFrame](#RmftbaD)
# * [Concatenation, keys, & MultiIndexes](#Ck&M)
# * [Concatenating vertically to get MultiIndexed rows](#CvtgMr)
# * [Slicing MultiIndexed DataFrames](#SMD)
# * [Concatenating horizontally to get MultiIndexed columns](#ChtgMc)
# * [Concatenating DataFrames from a dict](#CDfad)
# * [Outer & inner joins](#O&ij)
# * [Concatenating DataFrames with inner join](#CDwij)
# * [Resampling & concatenating DataFrames with inner join](#R&cDwij)
# * [Merging DataFrames](#MD)
# * [Merging company DataFrames](#McD)
# * [Merging on a specific column](#Moasc)
# * [Merging on columns with non-matching labels](#Mocwnl)
# * [Merging on multiple columns](#Momc)
# * [Joining DataFrames](#JD)
# * [Joining by Index](#JbI)
# * [Choosing a joining strategy](#Cajs)
# * [Left & right merging on multiple columns](#L&rmomc)
# * [Merging DataFrames with outer join](#MDwoj)
# * [Ordered merges](#Om)
# * [Using merge_ordered()](#Um)
# * [Using merge_asof()](#Um)
# * [Medals in the Summer Olympics](#MitSO)
# * [Loading Olympic edition DataFrame](#LOeD)
# * [Loading IOC codes DataFrame](#LIcD)
# * [Building medals DataFrame](#BmD)
# * [Quantifying Performance](#QP)
# * [Counting medals by country/edition in a pivot table](#Cmbciapt)
# * [Computing fraction of medals per Olympic edition](#CfompOe)
# * [Computing percentage change in fraction of medals won](#Cpcifomw)
# * [Reshaping and plotting](#Rap)
# * [Building hosts DataFrame](#BhD)
# * [Reshaping for analysis](#Rfa)
# * [Merging to compute influence](#Mtci)
# * [Plotting influence of host country](#Piohc)
# * [Final thoughts](#Ft)
# * [Team Anaconda](#TA)
# * [Tracks](#T)
# * [Collaborators](#C)
# * [Prerequisites](#P)
# * [Datasets](#D)

# %% [markdown]
# ## Bunch of sub markdowns

# %%
list_dict
# Out:
# [{'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='ItD'><p>\n", '### Introduction to Databases']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='RM'><p>\n", '### Relational Model']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CtyD'><p>\n", '### Connecting to your Database']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='EaCS'><p>\n", '### Engines and Connection Strings']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='ATfaD'><p>\n",
#    '### Autoloading Tables from a Database']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='VTD'><p>\n", '### Viewing Table Details']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='ItS'><p>\n", '### Introduction to SQL']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='SdfaTrS'><p>\n",
#    '### Selecting data from a Table: raw SQL']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='SdfaTwS'><p>\n",
#    '### Selecting data from a Table with SQLAlchemy']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='HaR'><p>\n", '### Handling a ResultSet']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='C'><p>\n", '### Congratulations!']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='FaTD'><p>\n", '### Filtering and Targeting Data']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CtaPD'><p>\n",
#    '### Connecting to a PostgreSQL Database']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='FdsfaT-S'><p>\n",
#    '### Filter data selected from a Table - Simple']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='FdsfaT-E'><p>\n",
#    '### Filter data selected from a Table - Expressions']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='FdsfaT-A'><p>\n",
#    '### Filter data selected from a Table - Advanced']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='OoO'><p>\n", '### Overview of Ordering']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='ObaSC'><p>\n", '### Ordering by a Single Column']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='OiDObaSC'><p>\n",
#    '### Ordering in Descending Order by a Single Column']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='ObMC'><p>\n", '### Ordering by Multiple Columns']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CSaGD'><p>\n",
#    '### Counting, Summing and Grouping Data']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CDD'><p>\n", '### Counting Distinct Data']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CoRbS'><p>\n", '### Count of Records by State']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='DtPSbS'><p>\n",
#    '### Determining the Population Sum by State']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='LuPaMtvoD'><p>\n",
#    "### Let's use Pandas and Matplotlib to visualize our Data"]},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='SRaPD'><p>\n",
#    '### SQLAlchemy ResultsProxy and Pandas Dataframes']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='FSrtaG'><p>\n",
#    '### From SQLAlchemy results to a Graph']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CViaQ'><p>\n", '### Calculating Values in a Query']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CtaMD'><p>\n", '### Connecting to a MySQL Database']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CaDbTC'><p>\n",
#    '### Calculating a Difference between Two Columns']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='DtOPoF'><p>\n",
#    '### Determining the Overall Percentage of Females']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='SR'><p>\n", '### SQL Relationships']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='AJwaER'><p>\n",
#    '### Automatic Joins with an Established Relationship']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='J'><p>\n", '### Joins']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='MPwJ'><p>\n", '### More Practice with Joins']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='WwHT'><p>\n", '### Working with Hierarchical Tables']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='Uathstjq'><p>\n",
#    '### Using alias to handle same table joined queries']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='LFaGwHD'><p>\n",
#    '### Leveraging Functions and Group_bys with Hierarchical Data']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='DwLR'><p>\n", '### Dealing with Large ResultSets']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='WoBoR'><p>\n", '### Working on Blocks of Records']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CDaT'><p>\n", '### Creating Databases and Tables']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CTwS'><p>\n", '### Creating Tables with SQLAlchemy']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CaDD'><p>\n", '### Constraints and Data Defaults']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='IDiaT'><p>\n", '### Inserting Data into a Table']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='Iasrwais'><p>\n",
#    '### Inserting a single row with an insert() statement']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='IMRaO'><p>\n",
#    '### Inserting Multiple Records at Once']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='LaCiaT'><p>\n", '### Loading a CSV into a Table']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='UDiaD'><p>\n", '### Updating Data in a Database']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='Uir'><p>\n", '### Updating individual records']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='UMR'><p>\n", '### Updating Multiple Records']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CU'><p>\n", '### Correlated Updates']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='RDFaD'><p>\n", '### Removing Data From a Database']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='Datrfat'><p>\n",
#    '### Deleting all the records from a table']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='Dsr'><p>\n", '### Deleting specific records']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='DaTC'><p>\n", '### Deleting a Table Completely']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CCS'><p>\n", '### Census Case Study']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='StEaM'><p>\n", '### Setup the Engine and MetaData']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='CtTttD'><p>\n", '### Create the Table to the Database']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='PtD'><p>\n", '### Populating the Database']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='RtDftC'><p>\n", '### Reading the Data from the CSV']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='LDfalitT'><p>\n",
#    '### Load Data from a list into the Table']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='EQ'><p>\n", '### Example Queries']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='BaQtDtAAbP'><p>\n",
#    '### Build a Query to Determine the Average Age by Population']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='BaQtDtPoPbGaS'><p>\n",
#    '### Build a Query to Determine the Percentage of Population by Gender and State']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='BaQtDtDbSft2a2C'><p>\n",
#    '### Build a Query to Determine the Difference by State from the 2000 and 2008 Censuses']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["<p id ='C'><p>\n", '### Congratulations']}]
